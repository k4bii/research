# %%
34 + 12
# Out:
# 46

# %%
'abc' * 3
# Out:
# 'abcabcabc'

# %%
3.14 * 2.8128
# Out:
# 8.832192000000001

# %%
list(range(5)) + list(range(10,15))
# Out:
# [0, 1, 2, 3, 4, 10, 11, 12, 13, 14]

# %%
34 + 12
# Out:
# 47

# %%
'abc' * 3
# Out:
# 'abcabcabcd'

# %%
3.14 * 2.8128
# Out:
# 8.832192000001001

# %%
list(range(5)) + list(range(10,15))
# Out:
# [0, 1, 2, 3, 4, 11, 12, 13, 14]
