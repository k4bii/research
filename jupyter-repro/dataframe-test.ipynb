# %%
import html_test

# %%
import pandas as pd

penguins = pd.read_csv(
    "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
)
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
import pandas as pd

iguanas = pd.read_csv(
    "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
)
iguanas
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
iguanas.eq(penguins)
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       True    True            True           True               True
# 1       True    True            True           True               True
# 2       True    True            True           True               True
# 3       True    True           False          False              False
# 4       True    True            True           True               True
# ..       ...     ...             ...            ...                ...
# 339     True    True           False          False              False
# 340     True    True            True           True               True
# 341     True    True            True           True               True
# 342     True    True            True           True               True
# 343     True    True            True           True               True
#
#      body_mass_g    sex
# 0           True   True
# 1           True   True
# 2           True   True
# ...

# %%
penguins.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 18.9 KB

# %%
import importlib
importlib.reload(html_test)

df = html_test.get_dataframe("dataframe-test.ipynb", 2)
df = df[df.iloc[:, 0].astype(str) != "..."].reset_index(drop=True)
df
# Out:
#   Unnamed: 0 species     island bill_length_mm bill_depth_mm  \
# 0          0  Adelie  Torgersen           39.1          18.7
# 1          1  Adelie  Torgersen           39.5          17.4
# 2          2  Adelie  Torgersen           40.3          18.0
# 3          3  Adelie  Torgersen            NaN           NaN
# 4          4  Adelie  Torgersen           36.7          19.3
# 5        339  Gentoo     Biscoe            NaN           NaN
# 6        340  Gentoo     Biscoe           46.8          14.3
# 7        341  Gentoo     Biscoe           50.4          15.7
# 8        342  Gentoo     Biscoe           45.2          14.8
# 9        343  Gentoo     Biscoe           49.9          16.1
#
#   flipper_length_mm body_mass_g     sex
# 0             181.0      3750.0    MALE
# 1             186.0      3800.0  FEMALE
# 2             195.0      3250.0  FEMALE
# 3               NaN         NaN     NaN
# 4             193.0      3450.0  FEMALE
# 5               NaN         NaN     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         10 non-null     str
#  1   species            10 non-null     str
#  2   island             10 non-null     str
#  3   bill_length_mm     8 non-null      str
#  4   bill_depth_mm      8 non-null      str
#  5   flipper_length_mm  8 non-null      str
#  6   body_mass_g        8 non-null      str
#  7   sex                8 non-null      str
# dtypes: str(8)
# memory usage: 772.0 bytes

# %%
from pandas.api.types import infer_dtype

dtype_summary = (
df.apply(lambda s: infer_dtype(s, skipna=True))
.rename("pd_infer_dtype_skipna")
.reset_index()
.rename(columns={"index": "column"})
)

# %%
dtype_summary.sort_values("pd_infer_dtype_skipna")
# Out:
#               column pd_infer_dtype_skipna
# 0         Unnamed: 0                string
# 1            species                string
# 2             island                string
# 3     bill_length_mm                string
# 4      bill_depth_mm                string
# 5  flipper_length_mm                string
# 6        body_mass_g                string
# 7                sex                string

# %%
dfn = df.convert_dtypes()
dfn
# Out:
#   Unnamed: 0 species     island bill_length_mm bill_depth_mm  \
# 0          0  Adelie  Torgersen           39.1          18.7
# 1          1  Adelie  Torgersen           39.5          17.4
# 2          2  Adelie  Torgersen           40.3          18.0
# 3          3  Adelie  Torgersen           <NA>          <NA>
# 4          4  Adelie  Torgersen           36.7          19.3
# 5        339  Gentoo     Biscoe           <NA>          <NA>
# 6        340  Gentoo     Biscoe           46.8          14.3
# 7        341  Gentoo     Biscoe           50.4          15.7
# 8        342  Gentoo     Biscoe           45.2          14.8
# 9        343  Gentoo     Biscoe           49.9          16.1
#
#   flipper_length_mm body_mass_g     sex
# 0             181.0      3750.0    MALE
# 1             186.0      3800.0  FEMALE
# 2             195.0      3250.0  FEMALE
# 3              <NA>        <NA>    <NA>
# 4             193.0      3450.0  FEMALE
# 5              <NA>        <NA>    <NA>
# ...

# %%
dfn.dtypes
# Out:
# Unnamed: 0           string
# species              string
# island               string
# bill_length_mm       string
# bill_depth_mm        string
# flipper_length_mm    string
# body_mass_g          string
# sex                  string
# dtype: object

# %%
dfn.eq(penguins)
# Out:
#      Unnamed: 0  bill_depth_mm  bill_length_mm  body_mass_g  \
# 0          <NA>          False           False        False
# 1          <NA>          False           False        False
# 2          <NA>          False           False        False
# 3          <NA>           <NA>            <NA>         <NA>
# 4          <NA>          False           False        False
# ..          ...            ...             ...          ...
# 339        <NA>           <NA>            <NA>         <NA>
# 340        <NA>           <NA>            <NA>         <NA>
# 341        <NA>           <NA>            <NA>         <NA>
# 342        <NA>           <NA>            <NA>         <NA>
# 343        <NA>           <NA>            <NA>         <NA>
#
#      flipper_length_mm  island   sex  species
# 0                False    True  True     True
# 1                False    True  True     True
# 2                False    True  True     True
# 3                 <NA>    True  <NA>     True
# ...

# %%
import pandas as pd

# pd.set_option("display.min_rows", 8)
penguins = pd.read_csv(
    "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
)
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
import importlib
importlib.reload(html_test)

df = html_test.get_dataframe("dataframe-test.ipynb", 4)
df = df[df.iloc[:, 0].astype(str) != "..."].reset_index(drop=True)
df
# Out:
#   Unnamed: 0 species island bill_length_mm bill_depth_mm flipper_length_mm  \
# 0          0    True   True           True          True              True
# 1          1    True   True           True          True              True
# 2          2    True   True           True          True              True
# 3          3    True   True          False         False             False
# 4          4    True   True           True          True              True
# 5        339    True   True          False         False             False
# 6        340    True   True           True          True              True
# 7        341    True   True           True          True              True
# 8        342    True   True           True          True              True
# 9        343    True   True           True          True              True
#
#   body_mass_g    sex
# 0        True   True
# 1        True   True
# 2        True   True
# 3       False  False
# 4        True   True
# ...

# %%
df
# Out:
#   Unnamed: 0 species island bill_length_mm bill_depth_mm flipper_length_mm  \
# 0          0    True   True           True          True              True
# 1          1    True   True           True          True              True
# 2          2    True   True           True          True              True
# 3          3    True   True          False         False             False
# 4          4    True   True           True          True              True
# 5        339    True   True          False         False             False
# 6        340    True   True           True          True              True
# 7        341    True   True           True          True              True
# 8        342    True   True           True          True              True
# 9        343    True   True           True          True              True
#
#   body_mass_g    sex
# 0        True   True
# 1        True   True
# 2        True   True
# 3       False  False
# 4        True   True
# ...

# %%
import pandas as pd

# pd.set_option("display.min_rows", 8)
# pd.set_option("display.max_colwidth", 6)
# pd.set_option("display.min_rows", 8)
penguins = pd.read_csv(
    "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
)
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
import importlib
importlib.reload(html_test)

df = html_test.get_dataframe("dataframe-test.ipynb", 6)
if df is None:
    df = penguins.copy()

df = df.set_index("species")
df.groupby(level="species").mean(numeric_only=True)
# Out:
#          Unnamed: 0.1  Unnamed: 0  bill_length_mm  bill_depth_mm  \
# species
# Adelie            2.0         2.0          38.900         18.350
# Gentoo            7.0       341.0          48.075         15.225
#
#          flipper_length_mm  body_mass_g
# species
# Adelie              188.75       3562.5
# Gentoo              215.50       5300.0

# %%
import pandas as pd

penguins = pd.read_csv(
    "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
)
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
import importlib
from io import StringIO

importlib.reload(html_test)

df_fixed, cleaned_html = html_test.parse_dataframe_with_bs4(
    "dataframe-test.ipynb",
    2,
    skiprows=[0],
    drop_ellipsis_rows=True,
    return_html=True,
)

df_from_clean_html = pd.read_html(StringIO(cleaned_html), skiprows=[0])[0]
df_from_clean_html.head()
# Out:
#      0  Adelie  Torgersen  39.1  18.7  181.0  3750.0    MALE
# 0    1  Adelie  Torgersen  39.5  17.4  186.0  3800.0  FEMALE
# 1    2  Adelie  Torgersen  40.3  18.0  195.0  3250.0  FEMALE
# 2    3  Adelie  Torgersen   NaN   NaN    NaN     NaN     NaN
# 3    4  Adelie  Torgersen  36.7  19.3  193.0  3450.0  FEMALE
# 4  339  Gentoo     Biscoe   NaN   NaN    NaN     NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10 entries, Adelie to Gentoo
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       10 non-null     int64
#  1   Unnamed: 0         10 non-null     int64
#  2   island             10 non-null     str
#  3   bill_length_mm     8 non-null      float64
#  4   bill_depth_mm      8 non-null      float64
#  5   flipper_length_mm  8 non-null      float64
#  6   body_mass_g        8 non-null      float64
#  7   sex                8 non-null      str
# dtypes: float64(4), int64(2), str(2)
# memory usage: 720.0+ bytes

# %%
df2 = df.infer_objects()
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10 entries, Adelie to Gentoo
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       10 non-null     int64
#  1   Unnamed: 0         10 non-null     int64
#  2   island             10 non-null     str
#  3   bill_length_mm     8 non-null      float64
#  4   bill_depth_mm      8 non-null      float64
#  5   flipper_length_mm  8 non-null      float64
#  6   body_mass_g        8 non-null      float64
#  7   sex                8 non-null      str
# dtypes: float64(4), int64(2), str(2)
# memory usage: 720.0+ bytes

# %%
df.loc[3, "bill_length_mm"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 df.loc[3, "bill_length_mm"]
#
# ...
