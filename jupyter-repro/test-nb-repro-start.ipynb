# %%
from nb_repro_start import NBRepro

r = NBRepro("basic-types-test.ipynb")
r.rerun()
r.compare()
# Out:
# [{'cell': 0,
#   'output': 0,
#   'match': True,
#   'reason': 'direct equality matched',
#   'details': {'approx_match_percent': 100.0},
#   'before': '46',
#   'after': '46'},
#  {'cell': 1,
#   'output': 0,
#   'match': True,
#   'reason': 'direct equality matched',
#   'details': {'approx_match_percent': 100.0},
#   'before': "'abcabcabc'",
#   'after': "'abcabcabc'"},
#  {'cell': 2,
#   'output': 0,
#   'match': True,
#   'reason': 'custom comparator matched',
#   'details': {'approx_match_percent': 100.0},
#   'before': '8.832192000000001',
#   'after': '8.832192000000001'},
#  {'cell': 3,
#   'output': 0,
#   'match': True,
#   'reason': 'direct equality matched',
#   'details': {'approx_match_percent': 100.0},
#   'before': '[0, 1, 2, 3, 4, 10, 11, 12, 13, 14]',
#   'after': '[0, 1, 2, 3, 4, 10, 11, 12, 13, 14]'},
#  {'cell': 4,
#   'output': 0,
#   'match': False,
#   'reason': 'direct equality mismatch',
#   'details': {'approx_match_percent': 97.87},
#   'before': '47',
# ...

# %%
k = NBRepro("intermediate-types-test.ipynb")
k.rerun()
k.compare()
# Out:
# species: ['True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True']
# island: ['True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True']
# bill_length_mm: ['True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True']
# bill_depth_mm: ['True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True']
# flipper_length_mm: ['True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True']
# body_mass_g: ['True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True']
# sex: ['True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True']
# confidence: 1.0 (80 true, 0 false)
#
#
# species: ['True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False']
# island: ['True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False']
# ...
